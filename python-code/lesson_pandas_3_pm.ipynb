# %%
# 결측치(NaN, NA) 처리 - 데이터가 누락되어 있는 것

# %%
import numpy as np
import pandas as pd

# %%
np.__version__
# Out:
# '2.0.0'

# %%
from numpy import nan

# %%
print(nan==True)
print(nan==False)
print(nan==0)
print(nan=='')
print(nan==nan)
# Out:
# False
# False
# False
# False
# False

# %%
pd.isnull(nan)
# Out:
# True

# %%
pd.notnull(nan)
# Out:
# False

# %%
pd.notnull(42)
# Out:
# True

# %%
visited = pd.read_csv('../doit_pandas-master/data/survey_visited.csv')
survey = pd.read_csv('../doit_pandas-master/data/survey_survey.csv')

# %%
visited.head(1)
# Out:
#    ident  site       dated
# 0    619  DR-1  1927-02-08

# %%
survey.head(1)
# Out:
#    taken person quant  reading
# 0    619   dyer   rad     9.82

# %%
vs = visited.merge(survey, left_on = 'ident', right_on = 'taken')

# %%
vs
# Out:
#     ident   site       dated  taken person quant  reading
# 0     619   DR-1  1927-02-08    619   dyer   rad     9.82
# 1     619   DR-1  1927-02-08    619   dyer   sal     0.13
# 2     622   DR-1  1927-02-10    622   dyer   rad     7.80
# 3     622   DR-1  1927-02-10    622   dyer   sal     0.09
# 4     734   DR-3  1939-01-07    734     pb   rad     8.41
# 5     734   DR-3  1939-01-07    734   lake   sal     0.05
# 6     734   DR-3  1939-01-07    734     pb  temp   -21.50
# 7     735   DR-3  1930-01-12    735     pb   rad     7.22
# 8     735   DR-3  1930-01-12    735    NaN   sal     0.06
# 9     735   DR-3  1930-01-12    735    NaN  temp   -26.00
# 10    751   DR-3  1930-02-26    751     pb   rad     4.35
# 11    751   DR-3  1930-02-26    751     pb  temp   -18.50
# 12    751   DR-3  1930-02-26    751   lake   sal     0.10
# 13    752   DR-3         NaN    752   lake   rad     2.19
# 14    752   DR-3         NaN    752   lake   sal     0.09
# ...

# %%
ebola = pd.read_csv('../doit_pandas-master/data/country_timeseries.csv')

# %%
ebola.count()
# Out:
# Date                   122
# Day                    122
# Cases_Guinea            93
# Cases_Liberia           83
# Cases_SierraLeone       87
# Cases_Nigeria           38
# Cases_Senegal           25
# Cases_UnitedStates      18
# Cases_Spain             16
# Cases_Mali              12
# Deaths_Guinea           92
# Deaths_Liberia          81
# Deaths_SierraLeone      87
# Deaths_Nigeria          38
# Deaths_Senegal          22
# Deaths_UnitedStates     18
# Deaths_Spain            16
# Deaths_Mali             12
# dtype: int64

# %%
num_rows = ebola.shape[0]

# %%
num_missing = num_rows - ebola.count()

# %%
print(num_missing)
# Out:
# Date                     0
# Day                      0
# Cases_Guinea            29
# Cases_Liberia           39
# Cases_SierraLeone       35
# Cases_Nigeria           84
# Cases_Senegal           97
# Cases_UnitedStates     104
# Cases_Spain            106
# Cases_Mali             110
# Deaths_Guinea           30
# Deaths_Liberia          41
# Deaths_SierraLeone      35
# Deaths_Nigeria          84
# Deaths_Senegal         100
# Deaths_UnitedStates    104
# Deaths_Spain           106
# Deaths_Mali            110
# dtype: int64

# %%
print(np.count_nonzero(ebola.isnull()))
# Out:
# 1214

# %%
print(np.count_nonzero(ebola['Cases_Guinea'].isnull()))
# Out:
# 29

# %%
ebola['Cases_Guinea'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 117    False
# 118    False
# 119    False
# 120    False
# 121    False
# Name: Cases_Guinea, Length: 122, dtype: bool

# %%
ebola.head(10)
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0    1/5/2015  289        2776.0            NaN            10030.0
# 1    1/4/2015  288        2775.0            NaN             9780.0
# 2    1/3/2015  287        2769.0         8166.0             9722.0
# 3    1/2/2015  286           NaN         8157.0                NaN
# 4  12/31/2014  284        2730.0         8115.0             9633.0
# 5  12/28/2014  281        2706.0         8018.0             9446.0
# 6  12/27/2014  280        2695.0            NaN             9409.0
# 7  12/24/2014  277        2630.0         7977.0             9203.0
# 8  12/21/2014  273        2597.0            NaN             9004.0
# 9  12/20/2014  272        2571.0         7862.0             8939.0
#
#    Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# 0            NaN            NaN                 NaN          NaN         NaN
# ...

# %%
ebola.interpolate().head(10)
# Out:
# C:\Users\201\AppData\Local\Temp\ipykernel_17184\28886440.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   ebola.interpolate().head(10)
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0    1/5/2015  289        2776.0            NaN            10030.0
# 1    1/4/2015  288        2775.0            NaN             9780.0
# 2    1/3/2015  287        2769.0         8166.0             9722.0
# 3    1/2/2015  286        2749.5         8157.0             9677.5
# 4  12/31/2014  284        2730.0         8115.0             9633.0
# 5  12/28/2014  281        2706.0         8018.0             9446.0
# 6  12/27/2014  280        2695.0         7997.5             9409.0
# 7  12/24/2014  277        2630.0         7977.0             9203.0
# 8  12/21/2014  273        2597.0         7919.5             9004.0
# ...

# %%
ebola.shape
# Out:
# (122, 18)

# %%
ebola_dropna = ebola.dropna()

# %%
ebola_dropna.shape
# Out:
# (1, 18)

# %%
ebola.shape
# Out:
# (122, 18)

# %%
ebola['Cases_multiple'] = ebola['Cases_Guinea']+ebola['Cases_Liberia']+ebola['Cases_SierraLeone']

# %%
ebola.head(5)
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0    1/5/2015  289        2776.0            NaN            10030.0
# 1    1/4/2015  288        2775.0            NaN             9780.0
# 2    1/3/2015  287        2769.0         8166.0             9722.0
# 3    1/2/2015  286           NaN         8157.0                NaN
# 4  12/31/2014  284        2730.0         8115.0             9633.0
#
#    Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# 0            NaN            NaN                 NaN          NaN         NaN
# 1            NaN            NaN                 NaN          NaN         NaN
# 2            NaN            NaN                 NaN          NaN         NaN
# 3            NaN            NaN                 NaN          NaN         NaN
# 4            NaN            NaN                 NaN          NaN         NaN
#
#    Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  \
# ...

# %%
ebola_subset = ebola.loc[:,['Cases_Guinea', 'Cases_Liberia', 'Cases_SierraLeone','Cases_multiple']]

# %%
ebola_subset
# Out:
#      Cases_Guinea  Cases_Liberia  Cases_SierraLeone  Cases_multiple
# 0          2776.0            NaN            10030.0             NaN
# 1          2775.0            NaN             9780.0             NaN
# 2          2769.0         8166.0             9722.0         20657.0
# 3             NaN         8157.0                NaN             NaN
# 4          2730.0         8115.0             9633.0         20478.0
# ..            ...            ...                ...             ...
# 117         103.0            8.0                6.0           117.0
# 118          86.0            NaN                NaN             NaN
# 119          86.0            NaN                NaN             NaN
# 120          86.0            NaN                NaN             NaN
# 121          49.0            NaN                NaN             NaN
#
# [122 rows x 4 columns]

# %%
ebola['Cases_Guinea']
# Out:
# 0      2776.0
# 1      2775.0
# 2      2769.0
# 3         NaN
# 4      2730.0
#         ...
# 117     103.0
# 118      86.0
# 119      86.0
# 120      86.0
# 121      49.0
# Name: Cases_Guinea, Length: 122, dtype: float64

# %%
ebola['Cases_Guinea'].sum(skipna=False)    # ['Cases_Guinea'] 파이썬 자체 표기법
# Out:
# np.float64(nan)

# %%
ebola.Cases_Guinea.sum()     # Cases_Guinea객체 표기법
# Out:
# np.float64(84729.0)
